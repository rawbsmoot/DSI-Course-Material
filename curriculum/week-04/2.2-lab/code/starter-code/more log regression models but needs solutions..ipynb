# %% [markdown]
# Inform Python we will use the StatsModels Library

# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Use IRIS Dataset

# %%
# import the dataset, declare target and features
iris = sm.datasets.get_rdataset('iris','datasets')
y = iris.data.Species 
X = x

# %%
x = st.add_constant(X, prepend = False)

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# 5             5.4          3.9           1.7          0.4
# 6             4.6          3.4           1.4          0.3
# 7             5.0          3.4           1.5          0.2
# 8             4.4          2.9           1.4          0.2
# 9             4.9          3.1           1.5          0.1
# 10            5.4          3.7           1.5          0.2
# 11            4.8          3.4           1.6          0.2
# 12            4.8          3.0           1.4          0.1
# 13            4.3          3.0           1.1          0.1
# 14            5.8          4.0           1.2          0.2
# 15            5.7          4.4           1.5          0.4
# 16            5.4          3.9           1.3          0.4
# 17            5.1          3.5           1.4          0.3
# 18            5.7          3.8           1.7          0.3
# 19            5.1          3.8           1.5          0.3
# 20            5.4          3.4           1.7          0.2
# 21            5.1          3.7           1.5          0.4
# 22            4.6          3.6           1.0          0.2
# 23            5.1          3.3           1.7          0.5
# 24            4.8          3.4           1.9          0.2
# 25            5.0          3.0           1.6          0.2
# 26            5.0          3.4           1.6          0.4
# 27            5.2          3.5           1.5          0.2
# 28            5.2          3.4           1.4          0.2
# 29            4.7          3.2           1.6          0.2
# ..            ...          ...           ...          ...
# 120           6.9          3.2           5.7          2.3
# 121           5.6          2.8           4.9          2.0
# 122           7.7          2.8           6.7          2.0
# 123           6.3          2.7           4.9          1.8
# 124           6.7          3.3           5.7          2.1
# 125           7.2          3.2           6.0          1.8
# 126           6.2          2.8           4.8          1.8
# 127           6.1          3.0           4.9          1.8
# 128           6.4          2.8           5.6          2.1
# 129           7.2          3.0           5.8          1.6
# 130           7.4          2.8           6.1          1.9
# 131           7.9          3.8           6.4          2.0
# 132           6.4          2.8           5.6          2.2
# 133           6.3          2.8           5.1          1.5
# 134           6.1          2.6           5.6          1.4
# 135           7.7          3.0           6.1          2.3
# 136           6.3          3.4           5.6          2.4
# 137           6.4          3.1           5.5          1.8
# 138           6.0          3.0           4.8          1.8
# 139           6.9          3.1           5.4          2.1
# 140           6.7          3.1           5.6          2.4
# 141           6.9          3.1           5.1          2.3
# 142           5.8          2.7           5.1          1.9
# 143           6.8          3.2           5.9          2.3
# 144           6.7          3.3           5.7          2.5
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# Setup the Logistic Regression

# %%
# add column of ones for our y-intercept (http://blog.yhat.com/posts/logistic-regression-and-python.html)
# nc = [x for x in if x != 'setosa']
# iris.ix[:, nc] = (iris.ix[:, nc] - iris.ix[:, nc].mean()) / iris.ix[:, nc].std()
iris = st.datasets.get_rdataset('iris','datasets')
y = iris.data.Species 
X = iris.data.ix[:, 0:4, le]

x = X.as_matrix(columns=None)
y = y.as_matrix(columns=None)
#declare our model
mdl = sm.MNLogit(y, x)
mdl_fit = mdl.fit()
mdl_fit.summary()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-39-24b8d1dadfc3> in <module>()
#       4 iris = st.datasets.get_rdataset('iris','datasets')
#       5 y = iris.data.Species
# ----> 6 X = iris.data.ix[:, 0:4, le]
#       7
#       8 x = X.as_matrix(columns=None)
#
# /Users/smoot/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      74                 pass
#      75
# ---> 76             return self._getitem_tuple(key)
#      77         else:
#      78             return self._getitem_axis(key, axis=0)
#
# /Users/smoot/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     783
#     784         # no multi-index, so validate all of the indexers
# --> 785         self._has_valid_tuple(tup)
#     786
#     787         # ugly hack for GH #836
#
# /Users/smoot/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_tuple(self, key)
#     135         for i, k in enumerate(key):
#     136             if i >= self.obj.ndim:
# --> 137                 raise IndexingError('Too many indexers')
#     138             if not self._has_valid_type(k, i):
#     139                 raise ValueError("Location based indexing can only have [%s] "
#
# IndexingError: Too many indexers

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5310c70af502> in <module>()
# ----> 1 results = logit.fit()
#
# NameError: name 'logit' is not defined

# %% [markdown]
# Perform the Regression using the Fit Method

# %%
print mdl_fit.aic
print mdl_fit.bic
# Out:
# 37.6798797268
# 61.7649620796

# %% [markdown]
# Print a summary of the results

# %%
mdl_margeff = mdl_fit.get_margeff()
mdl_margeff.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#        MNLogit Marginal Effects
# =====================================
# Dep. Variable:                      y
# Method:                          dydx
# At:                           overall
# ===============================================================================
#     y=setosa      dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# x1            1.055e-09   7.15e-06      0.000      1.000      -1.4e-05   1.4e-05
# x2            8.574e-10   6.14e-06      0.000      1.000      -1.2e-05   1.2e-05
# x3           -2.476e-09   1.64e-05     -0.000      1.000     -3.22e-05  3.22e-05
# x4            -2.65e-09   1.83e-05     -0.000      1.000     -3.59e-05  3.59e-05
# --------------------------------------------------------------------------------
# y=versicolor      dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# x1               0.1386      0.040      3.449      0.001         0.060     0.217
# x2               0.1450      0.038      3.860      0.000         0.071     0.219
# x3              -0.1847      0.060     -3.075      0.002        -0.302    -0.067
# x4              -0.2252      0.030     -7.633      0.000        -0.283    -0.167
# --------------------------------------------------------------------------------
# y=virginica      dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# x1             -0.1386      0.040     -3.449      0.001        -0.217    -0.060
# x2             -0.1450      0.038     -3.860      0.000        -0.219    -0.071
# x3              0.1847      0.060      3.075      0.002         0.067     0.302
# x4              0.2252      0.030      7.633      0.000         0.167     0.283
# ===============================================================================
# """
